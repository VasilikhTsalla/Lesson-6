# %% [markdown]
# # **Scraping με το newspaper3k**

# %% [markdown]
# Scraping, είναι η διαδικασία με την οποία συλλέγουμε περιεχόμενο από ιστοσελίδες στο διαδίκτυο.
#
# Με όρους προγραμματισμού, η διαδικασία είναι η εξής:
# - κάνουμε ένα αίτημα στο server της ιστοσελίδας: ορίζουμε το url της ιστοσελίδας και ζητάμε το περιεχόμενό της (δηλαδή τον html κώδικά της)
# - κατεβάζουμε τον html κώδικα (στον οποίο το περιεχόμενο είναι οργανωμένο μέσα σε html tags)
# - παίρνουμε το περιεχόμενο από τα tags που μας ενδιαφέρουν και το αποθηκεύουμε σε αντίστοιχες μεταβλητές (π.χ. αν πρόκειται για δημοσιογραφικό άρθρο, παίρνουμε τον τίτλο του, το κείμενο, τον συγγραφέα, την ημερομηνία δημοσίευσής του κλπ.)
#
# Στη συνέχεια, μπορούμε να οργανώσουμε όλες τις πληροφορίες που συλλέξαμε σε ένα dataframe για να τις επεξεργαστούμε και να τις αναλύσουμε.
#
# Το **newspaper** είναι ένα πακέτο για την python, με το οποίο μπορούμε με εύκολο τρόπο να συλλέξουμε περιεχόμενο από ειδησεογραφικές ιστοσελίδες.
#
#
#
# ---
#
#
# Sources:
# - Documentation: https://newspaper.readthedocs.io/en/latest/
# - Scraping websites with Newspaper3k in Python: https://www.geeksforgeeks.org/scraping-websites-with-newspaper3k-in-python/
# - Scrape and Summarize News Articles in 5 Lines of Python Code: https://towardsdatascience.com/scrape-and-summarize-news-articles-in-5-lines-of-python-code-175f0e5c7dfc

# %% [markdown]
# ### **Εγκατάσταση πακέτου**

# %% [markdown]
# Ξέρουμε ότι για να μπορούμε να χρησιμοποιήσουμε τις συναρτήσεις ενός πακέτου πρέπει πρώτα να το εισάγουμε.

# %%
import newspaper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-83b806c39519> in <cell line: 1>()
# ----> 1 import newspaper
#
# ModuleNotFoundError: No module named 'newspaper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Η εκτέλεση του παραπάνω import επέστρεψε ModuleNotFoundError, που σημαίνει ότι δεν βρέθηκε το πακέτο newspaper. Άρα πρέπει πρώτα να το εγκαταστήσουμε.
#
# Εκτελούμε την παρακάτω εντολή εγκατάστασης και **αφού εγκατασταθεί το μετατρέπουμε σε σχόλιο** (βάζοντας στην αρχή της εντολής #).

# %%
#!pip install newspaper3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (8.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.2)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.27.1)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.3 MB/s eta 0:00:00
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 9.6 MB/s eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 63.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.12.0)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13541 sha256=c60c5715af3d84e93f367d40f4d4221e53d84db892a0f13a6d9a48a32efcafc0
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=c6f09c8b93d83c3267021ef42f274bf12bbc08634e44981249c798055d0d9e82
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398382 sha256=e0235d5517212cab79754afc3446a5df40ddb3c4c1b45e178552ab235d23063b
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=c8a9940b35bcd8bb9c2761840c3f9600f52773872918fba55bd5cd79fd53c5f9
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.10 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.4.4

# %% [markdown]
# Τώρα μπορούμε να εισάγουμε το newspaper.

# %% [markdown]
# ### **Χρήση του newspaper και συλλογή άρθρων**

# %%
import newspaper

# %% [markdown]
# Όπως είπαμε παραπάνω, στην περιγραφή των βημάτων για το scraping, το πρώτο πράγμα που πρέπει να κάνουμε είναι να ορίσουμε το url της ειδησεογραφικής σελίδας από την οποία θα αντλήσουμε τα περιεχόμενα.
#
# Εδώ, θα συλλέξουμε άρθρα από την κατηγορία news του bbc.

# %%
site_url = "https://www.bbc.com/news"

# %%
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] Exceeded 30 redirects.

# %%
# get list of article URLs
urlsL = site.article_urls()

print(len(urlsL))
# print the first 10 articles urls
urlsL[:10]
# Out:
# 279
# ['https://www.bbc.com/news/world-60525350',
#  'https://www.bbc.com/news/science-environment-56837908',
#  'https://www.bbc.com/news/av/10462520',
#  'https://www.bbc.com/news/world',
#  'https://www.bbc.com/news/world/us_and_canada',
#  'https://www.bbc.com/news/uk',
#  'https://www.bbc.com/news/business',
#  'https://www.bbc.com/news/technology',
#  'https://www.bbc.com/news/science_and_environment',
#  'https://www.bbc.com/news/stories']

# %% [markdown]
# Έχουμε λοιπόν urls από το bbc.com/news.
#
# Τώρα, ας φέρουμε κάποια από τα άρθρα που υπάρχουν σε αυτά τα urls.

# %%
# import libraries
from newspaper import Article
import pandas as pd
import numpy as np

# %% [markdown]
# Για αρχή, ας φέρουμε το περιεχόμενο μόνο ενός άρθρου από το πρώτο url

# %%
article = Article(urlsL[0])
article.download()
article.parse()

# %% [markdown]
# Με τις παραπάνω εντολές, έχουμε κατεβάσει το πρώτο άρθρο και τώρα μπορούμε να δούμε το περιεχόμενό του. Ας δούμε τι έχουμε:

# %%
article.title
# Out:
# 'War in Ukraine'

# %%
article.text
# Out:
# 'Military equipment is being sent to support Ukraine, but President Zelensky says more is needed to stop Russia.\n\nRead more next'

# %%
article.authors
# Out:
# []

# %%
article.top_image
# Out:
# 'https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png'

# %%
article.images
# Out:
# {'...',
#  'https://a1.api.bbc.co.uk/hit.xiti?&col=1&from=p&ptag=js&s=598253&p=unknown&x2=[responsive]&x3=[bbc_website]&x4=[en]&x7=[index-section]&x8=[reverb-3.6.1-nojs]&x11=[news_gnl]&x12=[news]',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/07C4/production/_129788910_cc7ebd0608e23061d68e9622b5e5937ee602d915493_197_2469_13891000x563.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/10D38/production/_129802986_belgorod-index.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/10D7D/production/_129798986_moldovarally.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/122DB/production/_129795447_mediaitem129795444.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/1388/production/_129800050_zelensky_getty_21st_may.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/14E7F/production/_128413658_tank_promo-nc.png',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/14ECD/production/_129790758_gettyimages-1256368667.png',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/158AF/production/_129793288_karimkhan.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/16580/production/_129802519_mediaitem129802515.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/2286/production/_129783880_russian_defenses_promo_976-nc.png',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/3618/production/_128984831_gettyimages-1229810647.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/3DAC/production/_129788751_ce4e9861910a3a940b98d2351f2df270c4e5b9fe.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/4A0A/production/_129645981_230509_ukraine_bealebakhmut_013.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/ABA2/production/_129783934_6acecfb52de2b11251b9b6aa73efff1806ba63180_0_1200_7541000x628.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/AE40/production/_129780644_sunak-index-bbc.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/CB6D/production/_129777025_gettyimages-825880144.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/EAAE/production/_129787006_gettyimages-1471917211.jpg',
#  'https://ichef.bbci.co.uk/live-experience/cps/320/cpsprodpb/EF8E/production/_125662316_gettyimages-1143351798.jpg',
#  'https://ichef.bbci.co.uk/news/490/cpsprodpb/16580/production/_129802519_mediaitem129802515.jpg',
#  'https://sb.scorecardresearch.com/p?c1=2&c2=17986528&cs_ucfr=0&cv=2.0&cj=1',
#  'https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png',
#  'https://ychef.files.bbci.co.uk/width/320/p0fppytk.jpg'}

# %%
article.movies
# Out:
# []

# %%
article.publish_date

# %% [markdown]
# Αφού είδαμε ποιες πληροφορίες μπορούμε να πάρουμε για ένα url, ας φέρουμε αυτές τις πληροφορίες για τα 10 πρώτα urls κι ας τις οργανώσουμε σε ένα dataframe.

# %%
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)

# %%
news_df
# Out:
#                                                  url  date  \
# 0            https://www.bbc.com/news/world-60525350   NaN
# 1  https://www.bbc.com/news/science-environment-5...   NaN
# 2               https://www.bbc.com/news/av/10462520   NaN
# 3                     https://www.bbc.com/news/world   NaN
# 4       https://www.bbc.com/news/world/us_and_canada   NaN
# 5                        https://www.bbc.com/news/uk   NaN
# 6                  https://www.bbc.com/news/business   NaN
# 7                https://www.bbc.com/news/technology   NaN
# 8   https://www.bbc.com/news/science_and_environment   NaN
# 9                   https://www.bbc.com/news/stories   NaN
#
#                    title                                          top image  \
# 0         War in Ukraine  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 1               BBC News  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 2  One-minute World News  https://ichef.bbci.co.uk/news/1024/branded_new...
# 3               BBC News  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 4            US & Canada  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 5               BBC News  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 6               Business  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 7             Technology  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 8  Science & Environment  https://static.files.bbci.co.uk/ws/simorgh-ass...
# 9               BBC News  https://static.files.bbci.co.uk/ws/simorgh-ass...
#
#                                                 text authors  \
# 0  Military equipment is being sent to support Uk...      []
# 1  World likely to warm beyond key 1.5C limit by ...      []
# 2  Zelensky: For today, Bakhmut is only in our he...      []
# 3  Rohey Malick Lowe/Facbook Copyright: Rohey Mal...      []
# 4  Polls show about half of Democrats want the pa...      []
# 5  Mr Kelly, who has been in the role on an inter...      []
# 6  The Chinese-owned platform said the ban "infri...      []
# 7  The telecoms giant plans to shed up to 40% of ...      []
# 8  The Ynysgain centre is set to be sold off next...      []
# 9  TikTok profits from livestreams of families be...      []
#
#                                               images movies
# 0  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 1  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 2  {https://ichef.bbci.co.uk/images/ic/400xn/p0fp...     []
# 3  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 4  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 5  {https://ichef.bbci.co.uk/news/320/cpsprodpb/8...     []
# 6  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 7  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 8  {https://ichef.bbci.co.uk/live-experience/cps/...     []
# 9  {......     []

# %% [markdown]
# Ολόκληρος ο κώδικας για να φέρουμε το περιεχόμενο των άρθρων από ένα site

# %%
# define site url
site_url = "https://www.bbc.com/news"
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content (first 10)
articlesL = []
for url in urlsL[:10]:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

news_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] Exceeded 30 redirects.

# %% [markdown]
# ## **Άσκηση:** χρησιμοποιήστε τον παραπάνω κώδικα για να φτιάξετε ένα dataframe με άρθρα από το news247 και την efsyn.

# %% [markdown]
# **in.gr**

# %%
# define site url
site_url = "https://www.in.gr/latestnews/?page="
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content 
articlesL = []
for url in urlsL:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

newsingr_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.in.gr/feeds

# %%
newsingr_df
# Out:
#                                                    url                 date  \
# 0    https://www.in.gr/2023/05/21/world/ekloges-202...  2023-05-21 00:00:00
# 1    https://www.in.gr/2023/05/21/politics/politiki...  2023-05-21 00:00:00
# 2    https://www.in.gr/2023/05/20/greece/giorgos-ka...  2023-05-20 00:00:00
# 3    https://www.in.gr/2023/05/22/politics/diplomat...  2023-05-22 00:00:00
# 4    https://www.in.gr/2023/05/22/in-analysis/na-ps...  2023-05-22 00:00:00
# ..                                                 ...                  ...
# 539  https://www.in.gr/2023/05/22/politics/politiki...  2023-05-22 00:00:00
# 540  https://www.in.gr/2023/05/20/in-analysis/oi-po...  2023-05-20 00:00:00
# 541  https://www.in.gr/2023/05/22/politics/aftodioi...  2023-05-22 00:00:00
# 542  https://www.in.gr/2023/05/22/politics/aftodioi...  2023-05-22 00:00:00
# 543  https://www.in.gr/2023/05/22/politics/aftodioi...  2023-05-22 00:00:00
#
#                                                  title  \
# 0    Εκλογές 2023: Τι γράφουν τα ξένα μέσα ενημέρωσ...
# 1    10 στιγμές της τετραετίας που μπορεί να κρίνου...
# 2    Γιώργος Καραϊβάζ: Νέα ντοκουμέντα για τη δολοφ...
# 3    Χουλουσί Ακάρ: Το απρόσμενο τηλεφώνημα στον Νί...
# 4    «Να ψοφήσει η κατσίκα του γείτονα», δηλαδή ο Τ...
# ..                                                 ...
# 539  Εκλογές 2023: Τα όρια της δυσαρέσκειας, η συντ...
# 540  Οι πολίτες παίρνουν το λόγο: Γιατί να ψηφίσουν...
# 541  Να βάλουν δεξαμενές συλλογής νερού καλεί Δήμαρ...
# 542  Ο Περιφερειάρχης Πελοποννήσου θα διεκδικήσει κ...
# 543  Δημιουργείται Κέντρο Συλλογής Απορριμμάτων Ιχθ...
#
#                                              top image  \
# 0    https://www.in.gr/wp-content/uploads/2023/05/p...
# 1    https://www.in.gr/wp-content/uploads/2023/05/b...
# 2    https://www.in.gr/wp-content/uploads/2023/05/0...
# 3    https://www.in.gr/wp-content/uploads/2023/05/1...
# 4    https://www.in.gr/wp-content/uploads/2023/05/κ...
# ..                                                 ...
# 539  https://www.in.gr/wp-content/uploads/2023/05/n...
# 540  https://www.in.gr/wp-content/uploads/2023/05/o...
# 541  https://www.in.gr/wp-content/uploads/2023/05/I...
# 542  https://www.in.gr/wp-content/uploads/2023/05/p...
# 543  https://www.in.gr/wp-content/uploads/2023/05/I...
#
#                                                   text  \
# 0    Στενά παρακολουθούν την ανακοίνωση των εκλογικ...
# 1    Και να που φτάσαμε στο τέρμα – πέρασαν σχεδόν ...
# 2    Νέα στοιχεία έρχονται συνεχώς στο φως για τη δ...
# 3    Ένα απρόσμενο τηλεφώνημα δέχτηκε από τον Τούρκ...
# 4    Παρατηρώ τον τρόπο που γίνεται προσπάθεια να δ...
# ..                                                 ...
# 539  Αντικειμενικά είναι μια μεγάλη πολιτική επιτυχ...
# 540  Την περασμένη Τρίτη στο Αμφιθέατρο στο τέλος τ...
# 541  Έντονη είναι η ανησυχία μεταξύ των δημοτών Ερυ...
# 542  Ο Περιφερειάρχης Πελοποννήσου δήλωσε πως θα επ...
# 543  Όλα τα ζωικά και πλαστικά απόβλητα που δημιουρ...
#
#                                                authors  \
# 0    [Σύνταξη Ιν, Ολγα Στέφου, In.Gr Team, Ιωάννα Α...
# 1    [Μυρτώ Λιαλιούτη, Ολγα Στέφου, In.Gr Team, Ιωά...
# 2    [Σύνταξη Ιν, Ολγα Στέφου, In.Gr Team, Ιωάννα Α...
# 3    [Σύνταξη Ιν, Ολγα Στέφου, In.Gr Team, Ιωάννα Α...
# 4    [Λευτέρης Θ. Χαραλαμπόπουλος, Ολγα Στέφου, In....
# ..                                                 ...
# 539  [Παναγιώτης Σωτήρης, Ολγα Στέφου, In.Gr Team, ...
# 540  [Ελισσάβετ Φελώνη, Ολγα Στέφου, In.Gr Team, Ιω...
# 541  [Χρήστος Ράπτης, Ολγα Στέφου, In.Gr Team, Ιωάν...
# 542  [Σύνταξη Ιν, Ολγα Στέφου, In.Gr Team, Ιωάννα Α...
# 543  [Χρήστος Ράπτης, Ολγα Στέφου, In.Gr Team, Ιωάν...
#
#                                                 images movies
# 0    {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 1    {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 2    {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 3    {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 4    {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# ..                                                 ...    ...
# 539  {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 540  {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 541  {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 542  {https://www.ot.gr/wp-content/uploads/2023/04/...     []
# 543  {data:image/svg+xml;utf8;base64,PD94bWwgdmVyc2...     []
#
# [544 rows x 8 columns]

# %% [markdown]
# **cnn**

# %%
# define site url
site_url = "https://www.cnn.gr/eidhseis/?page="
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content 
articlesL = []
for url in urlsL:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

newscnn_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.cnn.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.cnn.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.cnn.gr/rss

# %%
newscnn_df
# Out:
#                                                    url  \
# 0                  https://www.cnn.gr/taksidi/featured
# 1    https://www.cnn.gr/politiki/story/364431/pros-...
# 2    https://www.cnn.gr/kosmos/story/364435/o-dyspi...
# 3    https://www.cnn.gr/kosmos/story/364427/to-meks...
# 4    https://www.cnn.gr/kosmos/story/364432/vretano...
# ..                                                 ...
# 347  https://www.cnn.gr/politiki/story/364311/elvet...
# 348  https://www.cnn.gr/politiki/story/364309/kastr...
# 349  https://www.cnn.gr/politiki/story/364269/sto-1...
# 350  https://www.cnn.gr/style/aytokinito/story/3634...
# 351  https://www.cnn.gr/taksidi/ellada/story/363872...
#
#                           date  \
# 0                          NaN
# 1    2023-05-22 22:45:16+03:00
# 2    2023-05-22 22:40:00+03:00
# 3    2023-05-22 22:32:00+03:00
# 4    2023-05-22 22:24:24+03:00
# ..                         ...
# 347  2023-05-22 13:50:44+03:00
# 348  2023-05-22 13:45:53+03:00
# 349  2023-05-22 11:04:42+03:00
# 350  2023-05-18 11:20:33+03:00
# 351  2023-05-20 10:16:00+03:00
#
#                                                  title  \
# 0
# 1    Προς εκλογές fast track – Πώς διαμορφώνεται η ...
# 2    Ο δύσπιστος Ερντογάν - Ήπιε νερό μόνο από τα χ...
# 3    Το Μεξικό προχωρά σε έκδοση βίζας εργατών από ...
# 4    Βρετανός επισκέφθηκε τα επτά σύγχρονα θαύματα ...
# ..                                                 ...
# 347          Ελβετία: Ποσοστά ρεκόρ για ΚΚΕ και ΜΕΡΑ25
# 348  «Κάστρο» της ΝΔ η Σαουδική Αραβία: Εντυπωσιακό...
# 349  Στο 16% το ποσοστό των κομμάτων εκτός Βουλής -...
# 350                      Το Rimac Nevera δεν πιάνεται!
# 351  Τουριστικό αφιέρωμα του CNBC σε Ελλάδα: Οι 7 ε...
#
#                                              top image  \
# 0    https://cdn.cnngreece.gr/templates/main/images...
# 1    https://cdn.cnngreece.gr/media/news/2023/05/22...
# 2    https://cdn.cnngreece.gr/media/news/2023/05/22...
# 3    https://cdn.cnngreece.gr/media/news/2023/05/22...
# 4    https://cdn.cnngreece.gr/media/news/2023/05/22...
# ..                                                 ...
# 347  https://cdn.cnngreece.gr/media/news/2023/05/22...
# 348  https://cdn.cnngreece.gr/media/news/2023/05/22...
# 349  https://cdn.cnngreece.gr/media/news/2023/05/22...
# 350  https://cdn.cnngreece.gr/media/news/2023/05/18...
# 351  https://cdn.cnngreece.gr/media/news/2023/05/20...
#
#                                                   text            authors  \
# 0    ΤΑΞΙΔΙ ΕΟΤ: Η Ελλάδα εμπειρία που αλλάζει τη ζ...                 []
# 1    Το εκλογικό αποτέλεσμα είναι αδύνατον να αμφισ...                 []
# 2    Το γύρο του διαδικτύου κάνει βίντεο με τον Ρετ...                 []
# 3    Στην ανακοίνωση πως η κυβέρνηση του Μεξικό , θ...                 []
# 4    Tα επτά θαύματα του σύγχρονου κόσμου κατάφερε ...                 []
# ..                                                 ...                ...
# 347  Ο Περισσός μπορεί να αισθάνεται υπερήφανος καθ...                 []
# 348  Εντυπωσιακά είναι τα ποσοστά που έλαβε η ΝΔ απ...                 []
# 349  Τα κόμματα που έμειναν εκτός Βουλής συγκεντρών...                 []
# 350  Το κροατικό ηλεκτρικό hypercar , το Nevera, εί...  [Γιάννης Σκουφής]
# 351  Στους 10 κορυφαίους τουριστικούς προορισμούς κ...                 []
#
#                                                 images movies
# 0    {https://cdn.cnngreece.gr/media/news/2023/05/1...     []
# 1    {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 2    {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 3    {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 4    {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# ..                                                 ...    ...
# 347  {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 348  {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 349  {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 350  {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
# 351  {https://cdn.cnngreece.gr/media/news/2023/05/2...     []
#
# [352 rows x 8 columns]

# %% [markdown]
# **Kathimerini**

# %%
# define site url
site_url = "https://www.kathimerini.gr/epikairothta/?page="
# get the content of the site
site = newspaper.build(site_url, memoize_articles=False)
# get list of article URLs
urlsL = site.article_urls()

# get articles content 
articlesL = []
for url in urlsL:
  articleD = {}
  article = Article(url)
  article.download()
  article.parse()
  articleD['url'] = url
  if article.publish_date is not None:
    articleD['date'] = article.publish_date
  else:
    articleD['date'] = np.nan
  if article.title is not None:
    articleD['title'] = article.title
  else:
    articleD['title'] = np.nan
  if article.top_image is not None:
    articleD['top image'] = article.top_image
  else:
    articleD['top image'] = np.nan
  if article.text is not None:
    articleD['text'] = article.text
  else:
    articleD['text'] = np.nan
  if article.authors is not None:
    articleD['authors'] = article.authors
  else:
    articleD['authors'] = np.nan
  if article.images is not None:
    articleD['images'] = article.images
  else:
    articleD['images'] = np.nan
  if article.movies is not None:
    articleD['movies'] = article.movies
  else:
    articleD['movies'] = np.nan
  articlesL.append(articleD)

newskathimerini_df = pd.DataFrame(articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://www.kathimerini.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 403 Client Error: Forbidden for url: https://www.kathimerini.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.kathimerini.gr/feeds

# %%
newskathimerini_df
# Out:
#                                                    url  \
# 0    https://summits.kathimerini.gr/summit/1st-athe...
# 1             https://www.kathimerini.gr/visual/video/
# 2    https://www.kathimerini.gr/economy/562433488/t...
# 3    https://www.kathimerini.gr/world/562434781/arg...
# 4    https://www.kathimerini.gr/politics/562434718/...
# ..                                                 ...
# 97   https://www.4troxoi.gr/epikairotita/kosmos/tot...
# 98   https://www.kathimerini.gr/athletics/562433905...
# 99   https://www.kathimerini.gr/world/562434115/par...
# 100  https://www.kathimerini.gr/life/562422661/lesv...
# 101  https://www.kathimerini.gr/k/travel/562416355/...
#
#                          date  \
# 0                         NaT
# 1                         NaT
# 2   2023-05-22 22:25:23+03:00
# 3   2023-05-22 22:22:11+03:00
# 4   2023-05-22 22:15:54+03:00
# ..                        ...
# 97  2023-05-21 11:29:37+03:00
# 98  2023-05-22 14:07:00+03:00
# 99  2023-05-22 12:26:45+03:00
# 100 2023-05-16 17:10:13+03:00
# 101 2023-05-12 13:08:13+03:00
#
#                                                  title  \
# 0                   Athens ESG & Climate Crisis Summit
# 1                                Video: Ιστορίες & Νέα
# 2    Τα στοιχήματα της επόμενης ημέρας για την οικο...
# 3    Αργεντινή: Κυκλοφόρησε το νέο χαρτονόμισμα των...
# 4    Εκλογές: Τι ψήφισαν οι Ελληνες στο εξωτερικό –...
# ..                                                 ...
# 97   Totem GT Electric: Η αναβίωση της Alfa Romeo G...
# 98   «Η La Liga ανήκει στους ρατσιστές»: Οργή για τ...
# 99   Παρίσι 2024: Σχέδιο για τοποθέτηση της Ολυμπια...
# 100       Λέσβος, ένα νησί που συνεχώς το ανακαλύπτεις
# 101  Ιορδανία: 5+1 στάσεις στη γοητευτική χώρα της ...
#
#                                              top image  \
# 0    https://summits.kathimerini.gr/wp-content/uplo...
# 1    https://www.kathimerini.gr/wp-content/themes/n...
# 2    https://www.kathimerini.gr/wp-content/uploads/...
# 3    https://www.kathimerini.gr/wp-content/uploads/...
# 4    https://www.kathimerini.gr/wp-content/uploads/...
# ..                                                 ...
# 97   https://www.4troxoi.gr/wp-content/uploads/2023...
# 98   https://www.kathimerini.gr/wp-content/uploads/...
# 99   https://www.kathimerini.gr/wp-content/uploads/...
# 100  https://www.kathimerini.gr/wp-content/uploads/...
# 101  https://www.kathimerini.gr/wp-content/uploads/...
#
#                                                   text  \
# 0    Στο πρώτο συνέδριο των «Καθημερινή Summits», θ...
# 1    Η «Κ» βρέθηκε στο κόκπιτ Mirage 2000-5 της Πολ...
# 2    Η πανδημία και η ενεργειακή κρίση που βάρυναν ...
# 3    Αργεντινή: Κυκλοφόρησε το νέο χαρτονόμισμα των...
# 4    Εκλογές: Τι ψήφισαν οι Ελληνες στο εξωτερικό –...
# ..                                                 ...
# 97   Η πρώτη Totem GT Electric που κατασκευάστηκε β...
# 98   «Η La Liga ανήκει στους ρατσιστές»: Οργή για τ...
# 99   Παρίσι 2024: Σχέδιο για τοποθέτηση της Ολυμπια...
# 100  Στις αλυκές της Καλλονής Λέσβου καταφθάνουν κά...
# 101  Η νύχτα έχει σκεπάσει τα πάντα. Στον εξώστη, μ...
#
#                       authors  \
# 0                          []
# 1                          []
# 2          [Ειρήνη Χρυσολωρά]
# 3                          []
# 4          [Λουκάς Βελιδάκης]
# ..                        ...
# 97   [Γιάννης Καλογερόπουλος]
# 98                         []
# 99                         []
# 100         [Ελένη Τζαννάτου]
# 101     [Αλεξάνδρα Μανδράκου]
#
#                                                 images movies
# 0    {https://summits.kathimerini.gr/wp-content/upl...     []
# 1    {https://www.kathimerini.gr/wp-content/uploads...     []
# 2    {https://www.kathimerini.gr/wp-content/themes/...     []
# 3    {https://www.kathimerini.gr/wp-content/themes/...     []
# 4    {https://www.kathimerini.gr/wp-content/themes/...     []
# ..                                                 ...    ...
# 97   {https://www.4troxoi.gr/wp-content/themes/gran...     []
# 98   {https://www.kathimerini.gr/wp-content/themes/...     []
# 99   {https://www.kathimerini.gr/wp-content/themes/...     []
# 100  {......     []
# 101  {https://www.kathimerini.gr/wp-content/themes/...     []
#
# [102 rows x 8 columns]
